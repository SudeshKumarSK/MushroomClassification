# %%
##############################################################################
## EE559 Final Project ===> Mushroom Classification.
## Created by Sudesh Kumar Santhosh Kumar and Thejesh Chandar Rao.
## Date: 6th May, 2023
## Tested in Python 3.10.9 using conda environment version 22.9.0.
##############################################################################

# %% [markdown]
# # Final Project -> Classification of Mushrooms (EE - 559)

# %% [markdown]
# ## TRAINING MACHINE LEARNING MODELS

# %% [markdown]
# # Importing all necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from utils.models import Model

# %% [markdown]
# ## Loading the dataset v1 from Encoding Directory which has the Encoded Features. (Every feature is numerical)

# %%
train_data_raw = pd.read_csv("./dataset/FeatureSelected/Statistical/Pearson/mushroom_train_v1.csv")

train_data_LDA = pd.read_csv("./dataset/FeatureTransformed/LDA/mushroom_train_pearson_v1_LDA.csv")

train_data_PCA_15 = pd.read_csv("./dataset/FeatureTransformed/PCA/mushroom_train_pearson_v1_PCA_15.csv")
train_data_PCA_30 = pd.read_csv("./dataset/FeatureTransformed/PCA/mushroom_train_pearson_v1_PCA_30.csv")
train_data_PCA_45 = pd.read_csv("./dataset/FeatureTransformed/PCA/mushroom_train_pearson_v1_PCA_45.csv")
train_data_PCA_60 = pd.read_csv("./dataset/FeatureTransformed/PCA/mushroom_train_pearson_v1_PCA_60.csv")
train_data_PCA_90 = pd.read_csv("./dataset/FeatureTransformed/PCA/mushroom_train_pearson_v1_PCA_90.csv")

# %%
train_data_raw.head()
# Out:
#    gill-attachment_cap-diameter_mean  gill-attachment_stem-width_min  \
# 0                          -0.780642                       -0.934151
# 1                          -0.780642                       -0.934151
# 2                          -0.780642                       -0.934151
# 3                           0.217808                       -0.290076
# 4                           2.529429                        1.770963
#
#    gill-attachment_stem-width_median  gill-attachment_cap-diameter_median  \
# 0                          -0.888140                            -1.035211
# 1                          -0.888140                            -1.035211
# 2                          -0.888140                            -1.035211
# 3                          -0.219145                             0.412609
# 4                           2.491033                             1.894900
#
#    stem-width  stem-color_stem-height_mean  gill-attachment_cap-diameter_min  \
# ...

# %%
train_data_LDA.head()
# Out:
#    feature 1  class
# 0  -0.140460    1.0
# 1   0.650066    1.0
# 2  -0.604854    0.0
# 3   1.280066    1.0
# 4  -1.146382    0.0

# %%
train_data_PCA_15.head()
# Out:
#    feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 0  -2.044241  -1.075478  -2.996924  -1.328030  -1.914894   1.713268
# 1   5.083060  -5.806458   0.618627  -2.898750  -0.207050  -2.450885
# 2   4.992989  -4.590637   2.178411   1.408308  -2.568579   1.141017
# 3  -0.664432   7.782737   1.175077  -5.433735  -2.677833   1.323598
# 4   1.893217   9.762262   0.935077   2.232654   1.676351  -2.394624
#
#    feature 7  feature 8  feature 9  feature 10  feature 11  feature 12  \
# 0  -1.914890  -2.024974  -0.031473   -0.735535    2.303524   -0.684423
# 1   4.243611  -0.068246   1.027185   -1.688267   -2.677212    0.243270
# 2  -1.632488   1.845564   4.830360   -0.967332   -3.381196    0.352605
# 3   0.101126  -0.278177  -0.710844    1.441606    0.493006    0.722771
# 4   0.775121  -2.175671  -1.396617   -0.875155   -2.512731    1.117893
#
#    feature 13  feature 14  feature 15  class
# 0    1.788594    0.135046   -0.401979    1.0
# ...

# %%
train_data_PCA_30.head()
# Out:
#    feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 
# 3  -0.664443   7.782707   1.175030  -5.433635  -2.679231   1.323999
# 4   1.893219   9.762260   0.935071   2.232627   1.676629  -2.394506
#
#    feature 7  feature 8  feature 9  feature 10  ...    feature 82  \
# 0  -1.914133  -2.025665  -0.033132   -0.732019  ... -1.894387e-14
# 1   4.243412  -0.068073   1.028012   -1.690258  ... -2.451538e-15
# 2  -1.632072   1.846520   4.827835   -0.966505  ...  3.393086e-15
# 3   0.099112  -0.280119  -0.702643    1.433643  ...  1.914711e-14
# 4   0.775407  -2.175666  -1.397459   -0.874789  ...  1.054936e-14
#
#      feature 83    feature 84    feature 85    feature 86    feature 87  \
# 0  2.079106e-14 -6.900896e-15 -2.230225e-15  4.024448e-16 -5.934520e-16
# ...

# %% [markdown]
# ## Separating Input Features and class labels from the dataset. Also Encoding the class labels from "p" -> 1 and "e" -> 0

# %%
## The below X_train is already Standardized and Shuffled.
# Select all the features except labels,
X_train_raw = train_data_raw.drop('class', axis=1)  

X_train_LDA = train_data_LDA.drop('class', axis=1) 

X_train_PCA_15 = train_data_PCA_15.drop('class', axis=1)
X_train_PCA_30 = train_data_PCA_30.drop('class', axis=1)
X_train_PCA_45 = train_data_PCA_45.drop('class', axis=1)
X_train_PCA_60 = train_data_PCA_60.drop("class", axis=1)
X_train_PCA_90 = train_data_PCA_90.drop("class", axis=1)

y_train = train_data_raw['class']  # Select only the 'class' column.

# %%
X_train_raw_np = X_train_raw.to_numpy() 
X_train_LDA_np = X_train_LDA.to_numpy() 

X_train_PCA_15_np = X_train_PCA_15.to_numpy() 
X_train_PCA_30_np = X_train_PCA_30.to_numpy() 
X_train_PCA_45_np = X_train_PCA_45.to_numpy() 
X_train_PCA_60_np = X_train_PCA_60.to_numpy() 
X_train_PCA_90_np = X_train_PCA_90.to_numpy() 

y_train_np = y_train.to_numpy()

# %% [markdown]
# ## Instantiating the Model class with an object.

# %%
model = Model()

# %% [markdown]
# ## Reference systems and analysis.

# %% [markdown]
# ### Reporting the performance of Trivial System on the Training Set.

# %%
train_accuracy_trivial = model.trivial_system(Y_true=y_train_np)
print(f"Accuracy of Training Data using the Trivial System is: {train_accuracy_trivial}")
# Out:
# Accuracy of Training Data using the Trivial System is: 50.62822315986873

# %% [markdown]
# ### Reporting the performance of Baseline System on the Training and Val Dataset to decide which dataset to proceed with for all other models.

# %%
result_baseline = model.train_Different_Data(X_train_raw_np, X_train_LDA_np, X_train_PCA_15_np, X_train_PCA_30_np, X_train_PCA_45_np, X_train_PCA_60_np, X_train_PCA_90_np, y_train_np, model_name="baseline")
result_baseline
# Out:
# Trained the baseline model on raw data successfully!
# Trained the baseline model on LDA transformed data successfully!
# Trained the baseline model on PCA_15 transformed data successfully!
# Trained the baseline model on PCA_30 transformed data successfully!
# Trained the baseline model on PCA_45 transformed data successfully!
# Trained the baseline model on PCA_60 transformed data successfully!
# Trained the baseline model on PCA_90 transformed data successfully!
# {'raw': (0.6589017815283638, 0.6537740271917487),
#  'LDA': (0.7692217533989686, 0.7706282231598687),
#  'PCA_15': (0.6488220815752461, 0.6452180028129395),
#  'PCA_30': (0.6573488045007032, 0.6518987341772152),
#  'PCA_45': (0.6585208626347867, 0.6545944678856072),
#  'PCA_60': (0.6587552742616034, 0.6540084388185654),
#  'PCA_90': (0.6589017815283638, 0.6537740271917487)}

# %%
result_LR= model.train_Different_Data(X_train_raw_np, X_train_LDA_np, X_train_PCA_15_np, X_train_PCA_30_np, X_train_PCA_45_np, X_train_PCA_60_np, X_train_PCA_90_np, y_train_np, model_name="perceptron")
result_LR
# Out:
# Trained the perceptron model on raw data successfully!
# Trained the perceptron model on LDA transformed data successfully!
# Trained the perceptron model on PCA_15 transformed data successfully!
# Trained the perceptron model on PCA_30 transformed data successfully!
# Trained the perceptron model on PCA_45 transformed data successfully!
# Trained the perceptron model on PCA_60 transformed data successfully!
# Trained the perceptron model on PCA_90 transformed data successfully!
# {'raw': (0.7407114392873887, 0.7427332395686826),
#  'LDA': (0.7211380684481951, 0.7235114861697141),
#  'PCA_15': (0.525111345522738, 0.5221518987341772),
#  'PCA_30': (0.6303328645100797, 0.6332630098452883),
#  'PCA_45': (0.6045475855602438, 0.610056258790436),
#  'PCA_60': (0.7407114392873887, 0.7427332395686826),
#  'PCA_90': (0.7407114392873887, 0.7427332395686826)}

# %%
result_Bayes = model.train_Different_Data(X_train_raw_np, X_train_LDA_np, X_train_PCA_15_np, X_train_PCA_30_np, X_train_PCA_45_np, X_train_PCA_60_np, X_train_PCA_90_np, y_train_np, model_name="BayesClf")
result_Bayes
# Out:
# Trained the BayesClf model on raw data successfully!
# Trained the BayesClf model on LDA transformed data successfully!
# Trained the BayesClf model on PCA_15 transformed data successfully!
# Trained the BayesClf model on PCA_30 transformed data successfully!
# Trained the BayesClf model on PCA_45 transformed data successfully!
# Trained the BayesClf model on PCA_60 transformed data successfully!
# Trained the BayesClf model on PCA_90 transformed data successfully!
# {'raw': (0.6509903891233005, 0.6516643225503985),
#  'LDA': (0.7741150961087669, 0.7749648382559775),
#  'PCA_15': (0.6506094702297234, 0.6454524144397562),
#  'PCA_30': (0.6611872948898265, 0.6629160806375997),
#  'PCA_45': (0.6901371308016878, 0.6854195968120019),
#  'PCA_60': (0.7478902953586498, 0.746601031411158),
#  'PCA_90': (0.7426746366619784, 0.7412095639943741)}

# %%
result_KNN = model.train_Different_Data(X_train_raw_np, X_train_LDA_np, X_train_PCA_15_np, X_train_PCA_30_np, X_train_PCA_45_np, X_train_PCA_60_np, X_train_PCA_90_np, y_train_np, model_name="KNN")
result_KNN
# Out:
# Trained the KNN model on raw data successfully!
# Trained the KNN model on LDA transformed data successfully!
# Trained the KNN model on PCA_15 transformed data successfully!
# Trained the KNN model on PCA_30 transformed data successfully!
# Trained the KNN model on PCA_45 transformed data successfully!
# Trained the KNN model on PCA_60 transformed data successfully!
# Trained the KNN model on PCA_90 transformed data successfully!
# {'raw': (0.9995897796530708, 0.9990623534927332),
#  'LDA': (0.8153715424285044, 0.7475386779184248),
#  'PCA_15': (0.998652133145804, 0.9975386779184248),
#  'PCA_30': (0.9991502578527895, 0.9978902953586498),
#  'PCA_45': (0.9995311767463666, 0.9990623534927332),
#  'PCA_60': (0.9996190811064228, 0.9990623534927332),
#  'PCA_90': (0.9995897796530708, 0.9990623534927332)}

# %%
# result_SVM = model.train_Different_Data(X_train_raw_np, X_train_LDA_np, X_train_PCA_15_np, X_train_PCA_30_np, X_train_PCA_45_np, X_train_PCA_60_np, X_train_PCA_90_np, y_train_np, model_name="SVM")
# result_SVM

# %%
result_MLP = model.train_Different_Data(X_train_raw_np, X_train_LDA_np, X_train_PCA_15_np, X_train_PCA_30_np, X_train_PCA_45_np, X_train_PCA_60_np, X_train_PCA_90_np, y_train_np, model_name="MLP")
result_MLP
# Out:
# Trained the MLP model on raw data successfully!
# Trained the MLP model on LDA transformed data successfully!
# /Users/sk/miniforge3/envs/ml/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Trained the MLP model on PCA_15 transformed data successfully!
# Trained the MLP model on PCA_30 transformed data successfully!
# Trained the MLP model on PCA_45 transformed data successfully!
