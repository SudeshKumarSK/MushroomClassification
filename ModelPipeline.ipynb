# %%
##############################################################################
## EE559 Final Project ===> Mushroom Classification.
## Created by Sudesh Kumar Santhosh Kumar and Thejesh Chandar Rao.
## Date: 6th May, 2023
## Tested in Python 3.10.9 using conda environment version 22.9.0.
##############################################################################

# %% [markdown]
# # Final Project -> Classification of Mushrooms (EE - 559)

# %% [markdown]
# ## TRAINING MACHINE LEARNING MODELS

# %% [markdown]
# # Importing all necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Loading the dataset v1 from Encoding Directory which has the Encoded Features. (Every feature is numerical)

# %%
train_data = pd.read_csv("./dataset/FeatureTransformed/PCA/mushroom_train_pearson_v1_PCA.csv")
print("Train Data Encoded-> 1: ")
train_data.head()
# Out:
# Train Data Encoded-> 1:
#    cap-diameter  stem-height  stem-width  cap-shape_cap-diameter_mean  \
# 0          4.98         6.04        6.21                     3.781002
# 1          2.84         5.66        3.55                     6.671073
# 2         11.44         7.03       25.29                     6.671073
# 3          8.77         4.44       13.61                     7.477626
# 4          7.55         8.41       18.44                     6.671073
#
#    cap-shape_cap-diameter_min  cap-shape_cap-diameter_max  \
# 0                        0.55                        7.89
# 1                        0.38                       30.48
# 2                        0.38                       30.48
# 3                        1.03                       25.60
# 4                        0.38                       30.48
#
#    cap-shape_cap-diameter_median  cap-shape_stem-height_mean  \
# 0                           4.25                    6.411460
# 1                           6.27                    6.849409
# 2                           6.27                    6.849409
# 3                           6.83                    5.541955
# 4                           6.27                    6.849409
#
#    cap-shape_stem-height_min  cap-shape_stem-height_max  ...  \
# 0                       2.24                      15.07  ...
# 1                       1.20                      24.63  ...
# 2                       1.20                      24.63  ...
# 3                       1.92                      11.50  ...
# 4                       1.20                      24.63  ...
#
#    season_cap-diameter_median  season_stem-height_mean  \
# 0                        6.06                 6.666083
# 1                        5.63                 6.613699
# 2                        6.54                 6.428729
# 3                        6.06                 6.666083
# 4                        6.06                 6.666083
#
#    season_stem-height_min  season_stem-height_max  season_stem-height_median  \
# 0                     0.0                   33.92                       6.01
# 1                     0.0                   33.03                       5.91
# 2                     0.0                   27.36                       6.02
# 3                     0.0                   33.92                       6.01
# 4                     0.0                   33.92                       6.01
#
#    season_stem-width_mean  season_stem-width_min  season_stem-width_max  \
# 0               12.087907                    0.0                 101.69
# 1               11.871272                    0.0                 103.91
# 2               13.801794                    0.0                  70.02
# 3               12.087907                    0.0                 101.69
# 4               12.087907                    0.0                 101.69
#
#    season_stem-width_median  class
# 0                     10.66      p
# 1                      9.33      p
# 2                     10.89      e
# 3                     10.66      p
# 4                     10.66      e
#
# [5 rows x 148 columns]

# %% [markdown]
# ## Separating Input Features and class labels from the dataset. Also Encoding the class labels from "p" -> 1 and "e" -> 0

# %%
X_train = train_data.drop('class', axis=1)  # Select all the features except labels,
y_train = train_data['class']  # Select only the 'class' column.

# %% [markdown]
# ##
